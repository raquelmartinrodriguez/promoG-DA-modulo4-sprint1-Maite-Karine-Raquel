# %%
# Importación de módulos y funciones necesarias
#from src import exploracion as exploracion
import pandas as pd 
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv("/Users/maite/Desktop/ADALAB/modulo-4/ejercicios/promoG-DA-modulo4-sprint1-Maite-Karine-Raquel/data/air_pollution new.csv", index_col = 0)
df1.head()
# Out:
#              country 2017  2018  2019  2020  2021  2022  2023
# city
# Kabul    Afghanistan    0  61.8  58.8  46.5  37.5  17.1  18.1
# Tirana       Albania    0     0     0  16.0  12.5  14.5  14.4
# Algiers      Algeria    0     0  21.2  20.2  20.0  17.8  17.4
# Ordino       Andorra    0     0     0   7.4   7.3   5.4   5.3
# Luanda        Angola    0     0  15.9  13.0  11.0   8.8   8.7

# %%
df1.columns
# Out:
# Index(['country', '2017', '2018', '2019', '2020', '2021', '2022', '2023'], dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 154

# %%
df1.isnull().sum()
# Out:
# country    0
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# 2021       0
# 2022       0
# 2023       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6985 entries, Kabul to Lusaka
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  6985 non-null   object
#  1   2017     6985 non-null   object
#  2   2018     6985 non-null   object
#  3   2019     6985 non-null   object
#  4   2020     6985 non-null   object
#  5   2021     6985 non-null   object
#  6   2022     6985 non-null   object
#  7   2023     6985 non-null   object
# dtypes: object(8)
# memory usage: 491.1+ KB

# %%
df2 = pd.read_excel("/Users/maite/Desktop/ADALAB/modulo-4/ejercicios/promoG-DA-modulo4-sprint1-Maite-Karine-Raquel/data/forest-cover-v1.xlsx")

# %%
df2.head()
# Out:
#   Country Name Country Code           Capital      Continent  Area (kmÂ²)  \
# 0        Aruba          ABW        Oranjestad  North America          180
# 1  Afghanistan          AFG             Kabul           Asia       652230
# 2       Angola          AGO            Luanda         Africa      1246700
# 3      Albania          ALB            Tirana         Europe        28748
# 4      Andorra          AND  Andorra la Vella         Europe          468
#
#    Population Density (per kmÂ²)  Population Growth Rate  \
# 0                       591.3611                  0.9991
# 1                        63.0587                  1.0257
# 2                        28.5466                  1.0315
# 3                        98.8702                  0.9957
# 4                       170.5641                  1.0100
#
#    World Population Percentage  Population Rank  Forest Area 1990  ...  \
# 0                         0.00              198          2.333333  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country Name                   214 non-null    object
#  1   Country Code                   214 non-null    object
#  2   Capital                        214 non-null    object
#  3   Continent                      214 non-null    object
#  4   Area (kmÂ²)                    214 non-null    int64
#  5   Population Density (per kmÂ²)  214 non-null    float64
#  6   Population Growth Rate         214 non-null    float64
#  7   World Population Percentage    214 non-null    float64
#  8   Population Rank                214 non-null    int64
#  9   Forest Area 1990               204 non-null    float64
#  10  Forest Area 1991               207 non-null    float64
#  11  Forest Area 1992               207 non-null    float64
# ...

# %%
df3 = pd.read_csv("/Users/maite/Desktop/ADALAB/modulo-4/ejercicios/promoG-DA-modulo4-sprint1-Maite-Karine-Raquel/data/Global Temperature.csv")

# %%
df3.head()
# Out:
#    Year   Month  Monthly Anomaly  Monthly Unc.   Annual Anomaly  Annual Unc  \
# 0  1850       1           -0.801         0.482              NaN         NaN
# 1  1850       2           -0.102         0.592              NaN         NaN
# 2  1850       3           -0.119         0.819              NaN         NaN
# 3  1850       4           -0.485         0.575              NaN         NaN
# 4  1850       5           -0.351         0.549              NaN         NaN
#
#   Five-Year Anomaly  Five-Year Unc.  Ten-Year Anomaly  Ten-Year Unc.  \
# 0               NaN             NaN               NaN            NaN
# 1               NaN             NaN               NaN            NaN
# 2               NaN             NaN               NaN            NaN
# 3               NaN             NaN               NaN            NaN
# 4               NaN             NaN               NaN            NaN
#
#     Twenty-Year Anomaly  Twenty-year Unc.
# 0                   NaN               NaN
# ...

# %%
df4 = pd.read_csv("/Users/maite/Desktop/ADALAB/modulo-4/ejercicios/promoG-DA-modulo4-sprint1-Maite-Karine-Raquel/data/global_air_pollution_data.csv")

# %%
df4.head()
# Out:
#          country_name         city_name  aqi_value aqi_category  \
# 0  Russian Federation        Praskoveya         51     Moderate
# 1              Brazil  Presidente Dutra         41         Good
# 2               Italy   Priolo Gargallo         66     Moderate
# 3              Poland         Przasnysz         34         Good
# 4              France          Punaauia         22         Good
#
#    co_aqi_value\t co_aqi_category  ozone_aqi_value ozone_aqi_category  \
# 0               1            Good               36               Good
# 1               1            Good                5               Good
# 2               1            Good               39               Good
# 3               1            Good               34               Good
# 4               0            Good               22               Good
#
#    no2_aqi_value no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category
# 0              0             Good               51           Moderate
# ...
