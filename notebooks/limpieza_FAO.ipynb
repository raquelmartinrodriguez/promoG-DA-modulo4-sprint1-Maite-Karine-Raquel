# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/maite/Desktop/ADALAB/modulo-4/ejercicios/promoG-DA-modulo4-sprint1-Maite-Karine-Raquel/data/cafe/FAO_cafe_exportaciones.csv", index_col = 0)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                                               Ámbito  Código del área (M49)  \
# Código del ámbito
# QCL                Cultivos y productos de ganadería                     24
# QCL                Cultivos y productos de ganadería                     24
# QCL                Cultivos y productos de ganadería                     24
# QCL                Cultivos y productos de ganadería                     24
# QCL                Cultivos y productos de ganadería                     24
#
#                      Área  Código del elemento    Elemento  \
# Código del ámbito
# QCL                Angola                 5510  Producción
# QCL                Angola                 5510  Producción
# QCL                Angola                 5510  Producción
# QCL                Angola                 5510  Producción
# QCL                Angola                 5510  Producción
#
#                    Código del producto (CPC)     Producto  Código del año  \
# Código del ámbito
# ...

# %%
df.columns
# Out:
# Index(['Ámbito', 'Código del área (M49)', 'Área', 'Código del elemento',
#        'Elemento', 'Código del producto (CPC)', 'Producto', 'Código del año',
#        'Año', 'Unidad', 'Valor', 'Símbolo', 'Descripción del Símbolo', 'Nota'],
#       dtype='object')

# %%
eliminar = ["Ámbito","Código del área (M49)", "Código del elemento","Código del producto (CPC)", "Nota"]
df_limpio = df.drop(columns= eliminar)
df_limpio.head()
# Out:
#                      Área    Elemento     Producto  Código del año   Año  \
# Código del ámbito
# QCL                Angola  Producción  Café, verde            2013  2013
# QCL                Angola  Producción  Café, verde            2014  2014
# QCL                Angola  Producción  Café, verde            2015  2015
# QCL                Angola  Producción  Café, verde            2016  2016
# QCL                Angola  Producción  Café, verde            2017  2017
#
#                       Unidad     Valor Símbolo Descripción del Símbolo
# Código del ámbito
# QCL                toneladas  12550.00       A           Cifra oficial
# QCL                toneladas  15009.00       A           Cifra oficial
# QCL                toneladas  15000.00       A           Cifra oficial
# QCL                toneladas  14679.61       I          Valor imputado
# QCL                toneladas  13542.99       I          Valor imputado

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 820 entries, QCL to QCL
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Área                     820 non-null    object
#  1   Elemento                 820 non-null    object
#  2   Producto                 820 non-null    object
#  3   Código del año           820 non-null    int64
#  4   Año                      820 non-null    int64
#  5   Unidad                   820 non-null    object
#  6   Valor                    820 non-null    float64
#  7   Símbolo                  820 non-null    object
#  8   Descripción del Símbolo  820 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 64.1+ KB

# %%
df_limpio.duplicated().sum()
# Out:
# 0

# %%
df_limpio.isnull().sum()
# Out:
# Área                       0
# Elemento                   0
# Producto                   0
# Código del año             0
# Año                        0
# Unidad                     0
# Valor                      0
# Símbolo                    0
# Descripción del Símbolo    0
# dtype: int64

# %%
df_limpio.to_csv("data/FAO_cafe_exportaciones_limpio.csv")

# %%
df = pd.read_csv("/Users/maite/Desktop/ADALAB/modulo-4/ejercicios/promoG-DA-modulo4-sprint1-Maite-Karine-Raquel/data/cafe/FAO_cafe_importacion.csv", index_col = 0)
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                               Ámbito  Código del área (M49)  \
# Código del ámbito
# TCL                Cultivos y productos de ganadería                      4
# TCL                Cultivos y productos de ganadería                      4
# TCL                Cultivos y productos de ganadería                      4
# TCL                Cultivos y productos de ganadería                      4
# TCL                Cultivos y productos de ganadería                      4
#
#                          Área  Código del elemento             Elemento  \
# Código del ámbito
# TCL                Afganistán                 5622  Importaciones Valor
# TCL                Afganistán                 5622  Importaciones Valor
# TCL                Afganistán                 5622  Importaciones Valor
# TCL                Afganistán                 5622  Importaciones Valor
# TCL                Afganistán                 5622  Importaciones Valor
#
# ...

# %%
df.columns
# Out:
# Index(['Ámbito', 'Código del área (M49)', 'Área', 'Código del elemento',
#        'Elemento', 'Código del producto (CPC)', 'Producto', 'Código del año',
#        'Año', 'Unidad', 'Valor', 'Símbolo', 'Descripción del Símbolo', 'Nota'],
#       dtype='object')

# %%
eliminar = ["Ámbito","Código del área (M49)", "Código del elemento","Código del producto (CPC)", "Nota"]
df_limpio = df.drop(columns= eliminar)
df_limpio.head()
# Out:
#                          Área             Elemento     Producto  \
# Código del ámbito
# TCL                Afganistán  Importaciones Valor  Café, verde
# TCL                Afganistán  Importaciones Valor  Café, verde
# TCL                Afganistán  Importaciones Valor  Café, verde
# TCL                Afganistán  Importaciones Valor  Café, verde
# TCL                Afganistán  Importaciones Valor  Café, verde
#
#                    Código del año   Año    Unidad  Valor Símbolo  \
# Código del ámbito
# TCL                          2013  2013  1000 US$      0       E
# TCL                          2014  2014  1000 US$     40       X
# TCL                          2015  2015  1000 US$    241       X
# TCL                          2016  2016  1000 US$      1       X
# TCL                          2017  2017  1000 US$     62       A
#
#                             Descripción del Símbolo
# Código del ámbito
# TCL                                  Valor estimado
# ...

# %%
df_limpio.duplicated().sum()
# Out:
# 0

# %%
df_limpio.isnull().sum()
# Out:
# Área                       0
# Elemento                   0
# Producto                   0
# Código del año             0
# Año                        0
# Unidad                     0
# Valor                      0
# Símbolo                    0
# Descripción del Símbolo    0
# dtype: int64

# %%
df_limpio.to_csv("data/FAO_cafe_importaciones_limpio.csv")
